# %%
# !pip install langchain langchain-groq langsmith -q

# %%
import os

# LangSmith Settings
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["LANGCHAIN_PROJECT"] = "Lab9-Agentic-AI"

# Groq API Key
os.environ["GROQ_API_KEY"] = "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"

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

print("Groq Model Loaded Successfully")
# Out:
# Groq Model Loaded Successfully

# %%
question = """
A shop sells pens at 12 rupees each.
If I buy 7 pens and pay with 100 rupees,
how much change will I receive?
"""

response = llm.invoke(question)

print("Question:")
print(question)

print("\nAnswer:")
print(response.content)
# Out:
# Question:
#
# A shop sells pens at 12 rupees each.
# If I buy 7 pens and pay with 100 rupees,
# how much change will I receive?
#
#
# Answer:
# To find the change, first, calculate the total cost of the pens.
#
# 7 pens * 12 rupees per pen = 84 rupees
#
# You paid with 100 rupees.
#
# Change = Amount paid - Total cost of pens
# Change = 100 rupees - 84 rupees
# Change = 16 rupees
#
# You will receive 16 rupees as change.
