# %%
# !pip install -q langchain langchain-community langchain-groq duckduckgo-search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.1-8b-instant",
    temperature=0.3
)

print("Groq Model Connected Successfully")
# Out:
# Groq Model Connected Successfully

# %%
# !pip install -U ddgs
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()

def search_agent(topic):
    print("Searching latest news...\n")
    return search.run(f"latest news about {topic}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 8.1 MB/s eta 0:00:00
# ...

# %%
def summariser_agent(raw_results):

    prompt = f"""
    Summarize the following news into exactly 3 short bullet points.

    News:
    {raw_results}
    """

    response = llm.invoke(prompt)

    return response.content

# %%
def report_agent(topic, summary):

    prompt = f"""
    Create a Markdown report.

    Title:
    # News: {topic}

    Include:

    - Heading
    - Summary
    - Three bullet points

    Summary:

    {summary}
    """

    response = llm.invoke(prompt)

    return response.content

# %%
topic = "artificial intelligence"

# Agent 1
raw_results = search_agent(topic)

print("\nSearch Results:")
print(raw_results)

# Agent 2
summary = summariser_agent(raw_results)

print("\nSummary:")
print(summary)

# Agent 3
report = report_agent(topic, summary)

print("\nMarkdown Report:")
print(report)

# Save report
with open("news_report.md", "w", encoding="utf-8") as file:
    file.write(report)

print("\nReport saved successfully as news_report.md")
# Out:
# Searching latest news...
#
#
# Search Results:
# ...

# %%
with open("news_report.md", "r", encoding="utf-8") as file:
    print(file.read())
# Out:
# # News: Artificial Intelligence
#
# ## Summary
#
# Here are 3 short bullet points summarizing the news:
#
# • Professor Emeritus Dimitri Bertsekas, a renowned computer scientist, has passed away at 83, leaving a legacy in fields such as control, optimization, and artificial intelligence.
# • Reuters and other sources provide the latest updates on AI news, including breakthroughs, technology trends, regulation, ethics, business, and global impact.
# • AI Weekly and other websites track and rank top AI stories, delivering curated news to professionals in the field, covering topics like machine learning, deep learning, and enterprise AI.
#
# ## Key Points
#
# * **Legacy of Dimitri Bertsekas**: The passing of Professor Emeritus Dimitri Bertsekas marks the end of an era in the field of artificial intelligence, with his contributions to control, optimization, and AI still being felt today.
# ...
