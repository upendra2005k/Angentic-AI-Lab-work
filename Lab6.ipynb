# %%
# !pip install pyautogen -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 8.5 MB/s eta 0:00:00

# %%
config_list = [{

    'model': 'llama-3.1-8b-instant',

    'api_key': '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',

    'base_url': 'https://api.groq.com/openai/v1'

}]

llm_config = {'config_list': config_list, 'temperature': 0.4}

# %%
import autogen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2869/2905596045.py in <cell line: 0>()
# ----> 1 import autogen
#
# ModuleNotFoundError: No module named 'autogen'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
